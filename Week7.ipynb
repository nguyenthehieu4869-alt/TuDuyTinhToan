# %%
#W7A1
def binary_search(arr, left, right, target):
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else: 
            right = mid -1
    return -1
arr = list(map(int, input().split()))
arr.sort()
target = int(input())
print(binary_search(arr, 0, len(arr)-1, target))

# %%
#W7A2
def count_occurrences(arr, x):
    count = 0
    for num in arr:
        if num == x:
            count += 1
    return count
arr = list(map(int, input().split()))
x = int(input())
print(count_occurrences(arr, x))

# %%
#W7A3
##Bubble Sort algorithm
def Bubble_sort(arr):
    for i in range(len(arr)):
        Swap = False
        for j in range(0, len(arr) -i -1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                Swap = True
        if not Swap:
            return arr
    return arr
arr = list(map(int, input().split()))
print(Bubble_sort(arr))

##Selection Sort algorithm
def Selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[j] < arr[i]:
                min_idx = j
                arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
arr = list(map(int, input().split()))
print(Selection_sort(arr))

# %%
#W7A4
a = list(map(int, input().split()))
b = []
c = []
for i in a:    
    if i not in b:
        b.append(i)
for i in b:
    c.append(a.count(i))
print(f"{b[c.index(max(c))]} xuat hien nhieu nhat, som nhat, {max(c)} lan")

# %%
#W7A5
a = list(map(int, input().split()))
X = int(input())
m = 0
for i in range(len(a)):
    for j in range(i+1, len(a)):
        if a[i] + a[j] == X:
            m += 1
print(m)

# %%
#W7A6
lst_1 = eval(input())
lst_2 = []
for i in lst_1:
    for j in i:
        lst_2.append(j)
print(lst_2)

# %%
#W7A7
a = eval(input())
b = [1] * len(a)
for i in range(len(a)):
    for j in range(i):
        if a[i] > a[j]:
            b[i] = max(b[i], b[j] + 1)
print(max(b))

# %%
#W7A8
interval = eval(input())
queries = eval(input())
interval.sort()
result = []

def find_x(i):
	res = 999999999999999
	left = 0
	right = len(interval) - 1
	while left <= right:
		mid = (left + right) // 2
		if i >= interval[mid][0] and i <= interval[mid][1]:
			res = min(res , interval[mid][1] - interval[mid][0] + 1)
			left = mid + 1
		else:
			right = mid -1
	left = 0
	right = len(interval) - 1
	while left <= right:
		mid = (left + right) // 2
		if i >= interval[mid][0] and i <= interval[mid][1]:
			res = min(res , interval[mid][1] - interval[mid][0] + 1)
			right = mid -1
		else:
			left = mid + 1
	if res == 999999999999999:
		res = -1
	return res

for i in queries:
	ans = find_x(i)
	result.append(ans)

print(result)

# %%
#W7A9
a = eval(input())
b = []
for i in range(len(a)):
    m = 0
    for j in range(i+1, len(a)):
        if a[i] > a[j]:
            m += 1
    b.append(m)
print(b)
# Out:
# [4, 3, 2, 1, 0]

# %%
#W7A10
nums = eval(input())
m = int(input())
a = []
for i in range(len(nums)):
    b = [nums[i]]
    a.append(b.copy())
    for j in range(i+1, len(nums)):
        b.append(nums[j])
        a.append(b.copy())
c = []
for q in a:
    c.append(sum(q) % m)
print(max(c))

# %%
#W7A11
sent = input().strip().split()
key_word = input().strip().split()
for i in range(len(sent)):
    if "." in sent[i]:
        sent[i] = sent[i].replace(".", "")
    elif "," in sent[i]:
        sent[i] = sent[i].replace(",", "")
cnt = 0
for j in range(len(sent)):
    if " ".join(sent[j:j+len(key_word)]) == " ".join(key_word):
        cnt += 1
print(cnt)

# %%
#W7A12
result = []
ans = ['A', 'B', 'C', 'D']
for i in range(4):
    a = input().strip()
    result.append((a, ans[i]))
result.sort(key = lambda x: x[0].lower())
print(" ".join(ans for _, ans in result))

# %%
#W7A13
n = int(input())
a = list(map(int, input().split()))
while n != len(a):
    a = list(map(int, input().split()))
b = 0
c = {}
for i in a:
    c[i] = c.get(i, 0) + 1
for j in c:
    if j + 1 in c:
        b = max(b, c[j] + c[j + 1])
print(b)

# %%
#W7A14
n = int(input())
a = list(map(int, input().split()))
while n != len(a):
    a = list(map(int, input().split()))
b = []
for i in range(len(a) - 1, -1, -1):
    if a[i] == 7:
        b.append(i)
if len(b) == 0:
    print("Not found")
print(*b, sep=' ')

# %%
#W7A15
n = int(input())
for _ in range(n):
    a = input().split()
for i in range(len(a)):
    if a[0] == 'Nemo':
        b = [a[len(a) - 1], a[1]]
    elif a[i] == 'Nemo':
        b = [a[i - 1], a[(i + 1) % len(a)]]
print(b[0], "and", b[1])
